# %% [markdown]
# ### 1. Exploring `HR_Dataset`

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hr_dataset = pd.read_csv('../data/HR_dataset/HR_Dataset.csv')
pd.options.display.max_columns = None
hr_dataset.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
#    PositionID                  Position State   Zip       DOB Sex MaritalDesc  \
# 0          19   Production Technician I    MA  1960  07/10/83  M       Single
# 1          27                   Sr. DBA    MA  2148  05/05/75  M      Married
# 2          20  Production Technician II    MA  1810  09/19/88   F     Married
# 3          19   Production Technician I    MA  1886  09/27/88   F     Married
# 4          19   Production Technician I    MA  2169  09/08/89   F    Divorced
#
#   CitizenDesc HispanicLatino RaceDesc DateofHire DateofTermination  \
# 0  US Citizen             No    White   7/5/2011               NaN
# 1  US Citizen             No    White  3/30/2015         6/16/2016
# 2  US Citizen             No    White   7/5/2011         9/24/2012
# 3  US Citizen             No    White   1/7/2008               NaN
# 4  US Citizen             No    White  7/11/2011          9/6/2016
#
#           TermReason        EmploymentStatus         Department  \
# 0  N/A-StillEmployed                  Active  Production
# 1      career change  Voluntarily Terminated              IT/IS
# 2              hours  Voluntarily Terminated  Production
# 3  N/A-StillEmployed                  Active  Production
# 4   return to school  Voluntarily Terminated  Production
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 0              4.60                5                     0
# 1              4.96                3                     6
# 2              3.02                3                     0
# 3              4.84                5                     0
# 4              5.00                4                     0
#
#   LastPerformanceReview_Date  DaysLateLast30  Absences
# 0                  1/17/2019               0         1
# 1                  2/24/2016               0        17
# 2                  5/15/2012               0         3
# 3                   1/3/2019               0        15
# 4                   2/1/2016               0         2

# %%
# let's clean the database = dtypes:
hr_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
#  13  State                       311 non-null    object
#  14  Zip                         311 non-null    int64
#  15  DOB                         311 non-null    object
#  16  Sex                         311 non-null    object
#  17  MaritalDesc                 311 non-null    object
#  18  CitizenDesc                 311 non-null    object
#  19  HispanicLatino              311 non-null    object
#  20  RaceDesc                    311 non-null    object
#  21  DateofHire                  311 non-null    object
#  22  DateofTermination           104 non-null    object
#  23  TermReason                  311 non-null    object
#  24  EmploymentStatus            311 non-null    object
#  25  Department                  311 non-null    object
#  26  ManagerName                 311 non-null    object
#  27  ManagerID                   303 non-null    float64
#  28  RecruitmentSource           311 non-null    object
#  29  PerformanceScore            311 non-null    object
#  30  EngagementSurvey            311 non-null    float64
#  31  EmpSatisfaction             311 non-null    int64
#  32  SpecialProjectsCount        311 non-null    int64
#  33  LastPerformanceReview_Date  311 non-null    object
#  34  DaysLateLast30              311 non-null    int64
#  35  Absences                    311 non-null    int64
# dtypes: float64(2), int64(16), object(18)
# memory usage: 87.6+ KB

# %%
hr_dataset.duplicated().sum()
# Out:
# 0

# %%
hr_dataset.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# PerformanceScore                0
# EngagementSurvey                0
# EmpSatisfaction                 0
# SpecialProjectsCount            0
# LastPerformanceReview_Date      0
# DaysLateLast30                  0
# Absences                        0
# dtype: int64

# %% [markdown]
# ___
# ___
# ### 2. Checking database mistakes
#
# 2.1. `MaritalStatusID`, `MaritalDesc` and `MarriedID`
#
# 2.2. `Termd`, `EmploymentStatus`, `DateofTermination` and `EmpStatusID`
#
# 2.3. `GenderID` and `Sex`
# ___

# %% [markdown]
# 2.1. Checking if `MaritalStatusID` matches with `MaritalDesc`

# %%
# Checking (visual) if value_counts matches:
print(f"MaritalStatusID values: \n\n{hr_dataset['MaritalStatusID'].value_counts()}")
print("------------------------------------\n")
print(f"MaritalDesc values: \n\n{hr_dataset['MaritalDesc'].value_counts()}")

# it seems to be
# Out:
# MaritalStatusID values:
#
# MaritalStatusID
# 0    137
# 1    124
# 2     30
# 3     12
# 4      8
# Name: count, dtype: int64
# ------------------------------------
#
# MaritalDesc values:
#
# MaritalDesc
# Single       137
# Married      124
# Divorced      30
# Separated     12
# Widowed        8
# Name: count, dtype: int64

# %%
# Creating a dict for checking manually if they are grouped as expected:
marital_desc_dict = dict(zip(hr_dataset['MaritalDesc'],hr_dataset['MaritalStatusID']))
marital_desc_dict
#it seems to be
# Out:
# {'Single': 0, 'Married': 1, 'Divorced': 2, 'Widowed': 4, 'Separated': 3}

# %%
for key, value in zip(hr_dataset['MaritalStatusID'],hr_dataset['MaritalDesc']):
    if key == marital_desc_dict[value]:
        continue
    else:
        print(hr_dataset['EmpID'])

# it seems to be perfect

# %%
#let's check more efficently:
pd.crosstab(hr_dataset['MaritalStatusID'], [hr_dataset['MarriedID'], hr_dataset['MaritalDesc']], rownames = ['MaritalStatusID'], colnames = ['MarriedID','MaritalDesc'])
# Out:
# MarriedID              0                                1
# MaritalDesc     Divorced Separated Single Widowed Married
# MaritalStatusID
# 0                      0         0    137       0       0
# 1                      0         0      0       0     124
# 2                     30         0      0       0       0
# 3                      0        12      0       0       0
# 4                      0         0      0       8       0

# %% [markdown]
# ___
# 2.2. Check between `Termd`, `EmploymentStatus`, `DateofTermination` and 	`EmpStatusID`

# %%
pd.crosstab(hr_dataset['EmpStatusID'], [hr_dataset['Termd'], hr_dataset['EmploymentStatus']], rownames = ['EmpStatusID'], colnames = ['Termd', 'EmploymentStatus'])
# Out:
# Termd                 0                    1
# EmploymentStatus Active Terminated for Cause Voluntarily Terminated
# EmpStatusID
# 1                   182                    2                      0
# 2                    11                    0                      0
# 3                    14                    0                      0
# 4                     0                   14                      0
# 5                     0                    0                     88

# %%
pd.crosstab(hr_dataset['Termd'], hr_dataset['DateofTermination'])
# Out:
# DateofTermination  1/11/2014  1/12/2014  1/12/2017  1/15/2016  1/2/2012  \
# Termd
# 1                          1          1          1          1         1
#
# DateofTermination  1/26/2016  1/7/2013  1/9/2013  1/9/2014  10/22/2011  \
# Termd
# 1                          1         1         1         1           1
#
# DateofTermination  10/25/2015  10/31/2014  10/31/2015  11/10/2018  11/11/2016  \
# Termd
# 1                           1           1           1           1           1
#
# DateofTermination  11/14/2015  11/15/2015  11/15/2016  11/30/2012  11/4/2015  \
# Termd
# 1                           1           1           1           1          2
#
# DateofTermination  12/12/2015  12/15/2015  12/28/2017  2/12/2016  2/19/2016  \
# Termd
# 1                           1           1           1          1          1
#
# DateofTermination  2/21/2016  2/22/2017  2/25/2018  2/4/2013  2/5/2016  \
# Termd
# 1                          1          1          1         1         1
#
# DateofTermination  2/8/2012  2/8/2016  3/15/2015  3/31/2014  4/1/2013  \
# Termd
# 1                         1         1          1          1         2
#
# DateofTermination  4/1/2016  4/15/2013  4/15/2015  4/15/2018  4/24/2014  \
# Termd
# 1                         1          1          1          1          1
#
# DateofTermination  4/29/2018  4/4/2014  4/6/2017  4/7/2012  4/7/2018  \
# Termd
# 1                          1         2         1         1         1
#
# DateofTermination  4/8/2015  5/1/2016  5/1/2018  5/14/2012  5/15/2014  \
# Termd
# 1                         1         1         1          1          1
#
# DateofTermination  5/17/2016  5/18/2016  5/25/2016  5/30/2011  6/15/2013  \
# Termd
# 1                          2          1          1          1          1
#
# DateofTermination  6/16/2016  6/18/2013  6/24/2013  6/25/2015  6/27/2015  \
# Termd
# 1                          1          2          1          1          1
#
# DateofTermination  6/29/2015  6/4/2015  6/4/2018  6/5/2013  6/6/2017  \
# Termd
# 1                          1         1         1         1         1
#
# DateofTermination  6/8/2016  7/2/2014  7/30/2018  7/8/2017  8/13/2018  \
# Termd
# 1                         1         1          1         1          1
#
# DateofTermination  8/15/2015  8/19/2012  8/19/2013  8/19/2018  8/2/2014  \
# Termd
# 1                          1          1          1          2         1
#
# DateofTermination  8/30/2010  8/4/2017  8/7/2014  9/1/2015  9/12/2015  \
# Termd
# 1                          1         1         1         1          1
#
# DateofTermination  9/15/2015  9/15/2016  9/19/2016  9/23/2016  9/24/2012  \
# Termd
# 1                          1          1          1          1          2
#
# DateofTermination  9/25/2013  9/26/2011  9/26/2017  9/26/2018  9/27/2018  \
# Termd
# 1                          1          1          1          1          1
#
# DateofTermination  9/29/2015  9/4/2014  9/5/2015  9/5/2016  9/6/2016  9/7/2015
# Termd
# 1                          1         1         1         1         1         2

# %% [markdown]
# It seems that ID 4 and 5 in `EmpStatusID` means that are terminated and indicates the reason. Let's check the relation between `EmpStatusID` == 1 | 2 | 3 and another field.

# %%
pd.crosstab(hr_dataset['EmpStatusID'], [hr_dataset['Termd'], hr_dataset['EmploymentStatus']], rownames = ['EmpStatusID'], colnames = ['Termd', 'EmploymentStatus'])
# Out:
# Termd                 0                    1
# EmploymentStatus Active Terminated for Cause Voluntarily Terminated
# EmpStatusID
# 1                   182                    2                      0
# 2                    11                    0                      0
# 3                    14                    0                      0
# 4                     0                   14                      0
# 5                     0                    0                     88

# %%
check_empstatusid = hr_dataset[(hr_dataset['EmpStatusID'] == 1) | (hr_dataset['EmpStatusID'] == 2) | (hr_dataset['EmpStatusID'] == 3)]

# %%
pd.crosstab(check_empstatusid['EmpStatusID'], check_empstatusid['CitizenDesc'])
# Out:
# CitizenDesc  Eligible NonCitizen  Non-Citizen  US Citizen
# EmpStatusID
# 1                              7            1         176
# 2                              0            0          11
# 3                              0            0          14

# %%
pd.crosstab(check_empstatusid['EmpStatusID'], check_empstatusid['TermReason'])
# Out:
# TermReason   Fatal attraction  N/A-StillEmployed  no-call, no-show
# EmpStatusID
# 1                           1                182                 1
# 2                           0                 11                 0
# 3                           0                 14                 0

# %% [markdown]
# There's relation between `Termd`, `EmploymentStatus`and `DateofTermination` but it is not clear the relation of them with `EmpStatusID`.

# %% [markdown]
# ___
# 2.3. Checking `GenderID` and `Sex`

# %%
pd.crosstab(hr_dataset['GenderID'], hr_dataset['Sex'])
# Out:
# Sex         F   M
# GenderID
# 0         176    0
# 1           0  135

# %% [markdown]
# ___
# ___
# ### 3. Data clean
#
# 3.1. Replacing `0-1` for `No-Yes`
#
# 3.2. `HispanicLatino` data format
#
# 3.3. Date fields format
#
# 3.4. Date fields format
#
# 3.5. Filling nulls
#
# 3.6. Removing duplicated positions for same ID
#
# 3.7. Correcting department data
#
# 3.8. Exporting cleaned data base
# ___

# %% [markdown]
# 3.1. Replacing `0-1` for `No-Yes`.

# %%
conv_bool = {0: 'No', 1: 'Yes'}

# %%
hr_dataset['MarriedID'] = hr_dataset['MarriedID'].map(conv_bool)
hr_dataset['Termd'] = hr_dataset['Termd'].map(conv_bool)
hr_dataset['FromDiversityJobFairID'] = hr_dataset['FromDiversityJobFairID'].map(conv_bool)
hr_dataset.sample(1)
# Out:
#       Employee_Name  EmpID MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 111  Gonzalez, Cayo  10031        No                2         1            1
#
#      DeptID  PerfScoreID FromDiversityJobFairID  Salary Termd  PositionID  \
# 111       5            4                    Yes   59892    No          19
#
#                     Position State   Zip       DOB Sex MaritalDesc  \
# 111  Production Technician I    MA  2108  09/29/69  M     Divorced
#
#     CitizenDesc HispanicLatino                   RaceDesc DateofHire  \
# 111  US Citizen             No  Black or African American  7/11/2011
#
#     DateofTermination         TermReason EmploymentStatus         Department  \
# 111               NaN  N/A-StillEmployed           Active  Production
#
#         ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 111  Brannon Miller       12.0  Diversity Job Fair          Exceeds
#
#      EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 111               4.5                4                     0
#
#     LastPerformanceReview_Date  DaysLateLast30  Absences
# 111                  2/18/2019               0         1

# %% [markdown]
# ___
# 3.2. `HispanicLatino` data format.

# %%
hr_dataset['HispanicLatino'].unique()
# Out:
# array(['No', 'Yes', 'no', 'yes'], dtype=object)

# %%
hr_dataset['HispanicLatino'] = hr_dataset['HispanicLatino'].apply(lambda x: x.title())

# %%
hr_dataset['HispanicLatino'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ___
# 3.3. Columns name

# %%
hr_dataset.rename(columns= {'MarriedID': 'Married', 'Termd': 'Term'}, inplace=True)

# %% [markdown]
# ___
# 3.4. Date fields format

# %%
hr_dataset['DOB'] = pd.to_datetime(hr_dataset['DOB'], format='%m/%d/%y')

# %%
def conv_dates(df, *cols):
    for col in cols:
        df[col] = pd.to_datetime(df[col], format='%m/%d/%Y')

# %%
conv_dates(hr_dataset, 'DateofHire', 'DateofTermination', 'LastPerformanceReview_Date')

# %%
hr_dataset.dtypes
# Out:
# Employee_Name                         object
# EmpID                                  int64
# Married                               object
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                object
# Salary                                 int64
# Term                                  object
# PositionID                             int64
# Position                              object
# State                                 object
# Zip                                    int64
# DOB                           datetime64[ns]
# Sex                                   object
# MaritalDesc                           object
# CitizenDesc                           object
# HispanicLatino                        object
# RaceDesc                              object
# DateofHire                    datetime64[ns]
# DateofTermination             datetime64[ns]
# TermReason                            object
# EmploymentStatus                      object
# Department                            object
# ManagerName                           object
# ManagerID                            float64
# RecruitmentSource                     object
# PerformanceScore                      object
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date    datetime64[ns]
# DaysLateLast30                         int64
# Absences                               int64
# dtype: object

# %% [markdown]
# ___
# 3.5. Filling nulls (in ManagerID):

# %%
hr_dataset['ManagerID'].isnull().sum()
# Out:
# 8

# %%
hr_dataset[hr_dataset['ManagerID'].isnull()][['ManagerID', 'ManagerName']]
# Out:
#      ManagerID     ManagerName
# 19         NaN  Webster Butler
# 30         NaN  Webster Butler
# 44         NaN  Webster Butler
# 88         NaN  Webster Butler
# 135        NaN  Webster Butler
# 177        NaN  Webster Butler
# 232        NaN  Webster Butler
# 251        NaN  Webster Butler

# %%
hr_dataset['ManagerID'].fillna(39, inplace=True)

# %%
hr_dataset['ManagerID'].isnull().sum()
# Out:
# 0

# %%
hr_dataset['ManagerID'] = hr_dataset['ManagerID'].astype(int)

# %%
hr_dataset['ManagerID'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ___
# 3.6. Correcting different positions for same PositionID

# %%
positions = hr_dataset[['PositionID', 'Position']]
positions.drop_duplicates(inplace= True)
positions.sort_values('PositionID')
# Out:
# /tmp/ipykernel_7087/311398892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positions.drop_duplicates(inplace= True)
#      PositionID                      Position
# 29            1                  Accountant I
# 132           2      Administrative Assistant
# 32            3            Area Sales Manager
# 70            4                  BI Developer
# 42            5                   BI Director
# 308           6                           CIO
# 240           7                Data Architect
# 18            8        Database Administrator
# 249           9                 Data Analyst
# 12            9                  Data Analyst
# 55           10        Director of Operations
# 131          11             Director of Sales
# 96           12                   IT Director
# 190          13            IT Manager - Infra
# 243          13               IT Manager - DB
# 76           13          IT Manager - Support
# 9            14                    IT Support
# 91           15              Network Engineer
# 150          16               President & CEO
# 290          17            Production Manager
# 27           18            Production Manager
# 0            19       Production Technician I
# 2            20      Production Technician II
# 60           21                 Sales Manager
# 162          22           Senior BI Developer
# 164          23       Shared Services Manager
# 227          23             Software Engineer
# 6            24             Software Engineer
# 35           25  Software Engineering Manager
# 26           26                Sr. Accountant
# 1            27                       Sr. DBA
# 59           28          Sr. Network Engineer
# 239          29      Principal Data Architect
# 25           30          Enterprise Architect

# %% [markdown]
# Let's see what's happening with the "Software Engineer" with PositionID 23 and 24:

# %%
hr_dataset[hr_dataset['Position'] == 'Software Engineer']
# Out:
#          Employee_Name  EmpID Married  MaritalStatusID  GenderID  EmpStatusID  \
# 6      Andreola, Colby  10194      No                0         0            1
# 37    Carabbio, Judith  10085      No                0         0            1
# 66   Del Bosque, Keyla  10155      No                0         0            1
# 86      Exantus, Susan  10290     Yes                1         0            4
# 180     Martin, Sandra  10110      No                0         0            1
# 212   Patronick, Lucas  10005      No                0         1            5
# 227        Quinn, Sean  10131     Yes                1         1            5
# 245       Saada, Adell  10126     Yes                1         0            1
# 274      Szabo, Andrew  10024      No                0         1            1
# 285       True, Edward  10102      No                0         1            5
#
#      DeptID  PerfScoreID FromDiversityJobFairID  Salary Term  PositionID  \
# 6         4            3                     No   95660   No          24
# 37        4            3                     No   93396   No          24
# 66        4            3                     No  101199   No          24
# 86        4            2                     No   99280  Yes          24
# 180       4            3                     No  105688   No          24
# 212       4            4                    Yes  108987  Yes          24
# 227       1            3                    Yes   83363  Yes          23
# 245       4            3                     No   86214   No          24
# 274       4            4                     No   92989   No          24
# 285       4            3                    Yes  100416  Yes          24
#
#               Position State   Zip        DOB Sex MaritalDesc  \
# 6    Software Engineer    MA  2110 1979-05-24   F      Single
# 37   Software Engineer    MA  2132 1987-04-05   F      Single
# 66   Software Engineer    MA  2176 1979-07-05   F      Single
# 86   Software Engineer    MA  1749 1987-05-15   F     Married
# 180  Software Engineer    MA  2135 1987-11-07   F      Single
# 212  Software Engineer    MA  1844 1979-02-20  M       Single
# 227  Software Engineer    MA  2045 1984-11-06  M      Married
# 245  Software Engineer    MA  2132 1986-07-24   F     Married
# 274  Software Engineer    MA  2140 1983-05-06  M       Single
# 285  Software Engineer    MA  2451 1983-06-14  M       Single
#
#              CitizenDesc HispanicLatino                   RaceDesc DateofHire  \
# 6             US Citizen             No                      White 2014-11-10
# 37            US Citizen             No                      White 2013-11-11
# 66            US Citizen             No  Black or African American 2012-01-09
# 86            US Citizen             No  Black or African American 2011-05-02
# 180           US Citizen             No                      Asian 2013-11-11
# 212           US Citizen             No  Black or African American 2011-11-07
# 227  Eligible NonCitizen             No  Black or African American 2011-02-21
# 245           US Citizen             No                      White 2012-11-05
# 274           US Citizen             No                      White 2014-07-07
# 285          Non-Citizen             No  Black or African American 2013-02-18
#
#     DateofTermination         TermReason        EmploymentStatus  \
# 6                 NaT  N/A-StillEmployed                  Active
# 37                NaT  N/A-StillEmployed                  Active
# 66                NaT  N/A-StillEmployed                  Active
# 86         2013-06-05         attendance    Terminated for Cause
# 180               NaT  N/A-StillEmployed                  Active
# 212        2015-09-07   Another position  Voluntarily Terminated
# 227        2015-08-15      career change  Voluntarily Terminated
# 245               NaT  N/A-StillEmployed                  Active
# 274               NaT  N/A-StillEmployed                  Active
# 285        2018-04-15     medical issues  Voluntarily Terminated
#
#                Department      ManagerName  ManagerID   RecruitmentSource  \
# 6    Software Engineering  Alex Sweetwater         10            LinkedIn
# 37   Software Engineering  Alex Sweetwater         10              Indeed
# 66   Software Engineering  Alex Sweetwater         10       CareerBuilder
# 86   Software Engineering  Alex Sweetwater         10              Indeed
# 180  Software Engineering  Alex Sweetwater         10       Google Search
# 212  Software Engineering  Alex Sweetwater         10  Diversity Job Fair
# 227  Software Engineering       Janet King          2  Diversity Job Fair
# 245  Software Engineering  Alex Sweetwater         10              Indeed
# 274  Software Engineering  Alex Sweetwater         10            LinkedIn
# 285  Software Engineering  Alex Sweetwater         10  Diversity Job Fair
#
#       PerformanceScore  EngagementSurvey  EmpSatisfaction  \
# 6          Fully Meets              3.04                3
# 37         Fully Meets              4.96                4
# 66         Fully Meets              3.79                5
# 86   Needs Improvement              2.10                5
# 180        Fully Meets              4.50                5
# 212            Exceeds              5.00                5
# 227        Fully Meets              4.15                4
# 245        Fully Meets              4.20                3
# 274            Exceeds              4.50                5
# 285        Fully Meets              4.60                3
#
#      SpecialProjectsCount LastPerformanceReview_Date  DaysLateLast30  Absences
# 6                       4                 2019-01-02               0        19
# 37                      6                 2019-01-30               0         3
# 66                      5                 2019-01-25               0         8
# 86                      4                 2012-08-10               4        19
# 180                     4                 2019-01-14               0        14
# 212                     3                 2015-08-16               0        13
# 227                     0                 2014-04-19               0         4
# 245                     6                 2019-02-13               0         2
# 274                     5                 2019-02-18               0         1
# 285                     4                 2017-02-12               0         9

# %%
hr_dataset[hr_dataset['PositionID'] == 23]
# Out:
#            Employee_Name  EmpID Married  MaritalStatusID  GenderID  \
# 164  LeBlanc, Brandon  R  10134     Yes                1         1
# 227          Quinn, Sean  10131     Yes                1         1
#
#      EmpStatusID  DeptID  PerfScoreID FromDiversityJobFairID  Salary Term  \
# 164            1       1            3                     No   93046   No
# 227            5       1            3                    Yes   83363  Yes
#
#      PositionID                 Position State   Zip        DOB Sex  \
# 164          23  Shared Services Manager    MA  1460 1984-06-10  M
# 227          23        Software Engineer    MA  2045 1984-11-06  M
#
#     MaritalDesc          CitizenDesc HispanicLatino  \
# 164     Married           US Citizen             No
# 227     Married  Eligible NonCitizen             No
#
#                       RaceDesc DateofHire DateofTermination  \
# 164                      White 2016-01-05               NaT
# 227  Black or African American 2011-02-21        2015-08-15
#
#             TermReason        EmploymentStatus            Department  \
# 164  N/A-StillEmployed                  Active         Admin Offices
# 227      career change  Voluntarily Terminated  Software Engineering
#
#     ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 164  Janet King          2       CareerBuilder      Fully Meets
# 227  Janet King          2  Diversity Job Fair      Fully Meets
#
#      EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 164              4.10                4                     0
# 227              4.15                4                     0
#
#     LastPerformanceReview_Date  DaysLateLast30  Absences
# 164                 2019-01-28               0        20
# 227                 2014-04-19               0         4

# %% [markdown]
# Clearly (looking at Manager), what makes more sense is that the incorrect data is Position, and is Position ID the correct data:

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 23] = "Shared Services Manager"
# Out:
# /tmp/ipykernel_7087/2229378613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_dataset['Position'][hr_dataset['PositionID'] == 23] = "Shared Services Manager"

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 23].value_counts()
# Out:
# Position
# Shared Services Manager    2
# Name: count, dtype: int64

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 13].value_counts()
# Out:
# Position
# IT Manager - DB         2
# IT Manager - Support    1
# IT Manager - Infra      1
# Name: count, dtype: int64

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 13] = 'IT Manager'
# Out:
# /tmp/ipykernel_7087/3064531365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_dataset['Position'][hr_dataset['PositionID'] == 13] = 'IT Manager'

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 13].value_counts()
# Out:
# Position
# IT Manager    4
# Name: count, dtype: int64

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 9].value_counts()
# Out:
# Position
# Data Analyst     7
# Data Analyst     1
# Name: count, dtype: int64

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 9] = '../data Analyst'
# Out:
# /tmp/ipykernel_7087/3996302974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_dataset['Position'][hr_dataset['PositionID'] == 9] = 'Data Analyst'

# %%
hr_dataset['Position'][hr_dataset['PositionID'] == 9].value_counts()
# Out:
# Position
# Data Analyst    8
# Name: count, dtype: int64

# %% [markdown]
# ___
# 3.7. Cleaning Department ID and Department errors

# %%
depts = hr_dataset[['DeptID', 'Department']]
depts.drop_duplicates(inplace= True)
depts.sort_values('DeptID')
# Out:
# /tmp/ipykernel_7087/2358347294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depts.drop_duplicates(inplace= True)
#      DeptID            Department
# 26        1         Admin Offices
# 227       1  Software Engineering
# 150       2      Executive Office
# 1         3                 IT/IS
# 6         4  Software Engineering
# 0         5     Production
# 32        6                 Sales
# 64        6     Production

# %% [markdown]
# Let's correct the name of production's department:

# %%
depts.loc[64,'Department']
# Out:
# 'Production       '

# %%
hr_dataset['Department'][hr_dataset['Department'] == depts.loc[64,'Department']]  = 'Production'
# Out:
# /tmp/ipykernel_7087/632984008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_dataset['Department'][hr_dataset['Department'] == depts.loc[64,'Department']]  = 'Production'

# %% [markdown]
# Let's check if, the lines where DeptID == 6, and the Department == Production, what data is correct:

# %%
hr_dataset[hr_dataset['DeptID'] == 6].sort_values('Department').head()
# Out:
#         Employee_Name  EmpID Married  MaritalStatusID  GenderID  EmpStatusID  \
# 64         Dee, Randy  10311     Yes                1         1            1
# 32   Bunbury, Jessica  10188     Yes                1         0            5
# 282    Torrence, Jack  10013      No                3         1            1
# 278  Terry, Sharlene   10161      No                0         0            1
# 270   Strong, Caitrin  10241     Yes                1         0            1
#
#      DeptID  PerfScoreID FromDiversityJobFairID  Salary Term  PositionID  \
# 64        6            1                     No   56991   No          19
# 32        6            3                     No   74326  Yes           3
# 282       6            4                     No   64397   No           3
# 278       6            3                     No   58370   No           3
# 270       6            3                     No   60120   No           3
#
#                     Position State    Zip        DOB Sex MaritalDesc  \
# 64   Production Technician I    MA   2138 1988-04-15  M      Married
# 32        Area Sales Manager    VA  21851 2064-06-01   F     Married
# 282       Area Sales Manager    ND  58782 2068-01-15  M    Separated
# 278       Area Sales Manager    OR  97756 2065-05-07   F      Single
# 270       Area Sales Manager    MT  59102 1989-05-12   F     Married
#
#              CitizenDesc HispanicLatino                   RaceDesc DateofHire  \
# 64            US Citizen             No                      White 2018-07-09
# 32   Eligible NonCitizen             No  Black or African American 2011-08-15
# 282           US Citizen             No                      White 2006-01-09
# 278           US Citizen             No  Black or African American 2014-09-29
# 270           US Citizen             No  Black or African American 2010-09-27
#
#     DateofTermination         TermReason        EmploymentStatus  Department  \
# 64                NaT  N/A-StillEmployed                  Active  Production
# 32         2014-08-02   Another position  Voluntarily Terminated       Sales
# 282               NaT  N/A-StillEmployed                  Active       Sales
# 278               NaT  N/A-StillEmployed                  Active       Sales
# 270               NaT  N/A-StillEmployed                  Active       Sales
#
#         ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 64   Brannon Miller         12            Indeed      Fully Meets
# 32       John Smith         17     Google Search      Fully Meets
# 282   Lynn Daneault         21            Indeed          Exceeds
# 278   Lynn Daneault         21            Indeed      Fully Meets
# 270      John Smith         17            Indeed      Fully Meets
#
#      EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 64               4.30                4                     3
# 32               3.14                5                     0
# 282              4.10                3                     0
# 278              3.69                3                     0
# 270              4.10                4                     0
#
#     LastPerformanceReview_Date  DaysLateLast30  Absences
# 64                  2019-01-31               2         2
# 32                  2013-02-10               1        19
# 282                 2019-01-04               0         6
# 278                 2019-01-28               0        18
# 270                 2019-01-31               0        18

# %%
hr_dataset['Department'][hr_dataset['ManagerName'] == 'Brannon Miller'].value_counts()
# Out:
# Department
# Production    22
# Name: count, dtype: int64

# %%
hr_dataset['DeptID'][hr_dataset['ManagerName'] == 'Brannon Miller'].value_counts()
# Out:
# DeptID
# 5    21
# 6     1
# Name: count, dtype: int64

# %% [markdown]
# The correct one, then, is the Department ID:

# %%
hr_dataset['DeptID'][hr_dataset['Department'] == 'Production'] = 5
# Out:
# /tmp/ipykernel_7087/3799844433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_dataset['DeptID'][hr_dataset['Department'] == 'Production'] = 5

# %%
hr_dataset['DeptID'][hr_dataset['ManagerName'] == 'Brannon Miller'].value_counts()
# Out:
# DeptID
# 5    22
# Name: count, dtype: int64

# %% [markdown]
# Let's check now the values where DeptID == 1:

# %%
hr_dataset['Department'][hr_dataset['DeptID'] == 1].value_counts()
# Out:
# Department
# Admin Offices           9
# Software Engineering    1
# Name: count, dtype: int64

# %%
hr_dataset[hr_dataset['DeptID'] == 1].sort_values('Department', ascending= False)
# Out:
#             Employee_Name  EmpID Married  MaritalStatusID  GenderID  \
# 227           Quinn, Sean  10131     Yes                1         1
# 26      Boutwell, Bonalyn  10081     Yes                1         0
# 29             Brown, Mia  10238     Yes                1         0
# 97      Foster-Baker, Amy  10080     Yes                1         0
# 132       Howard, Estelle  10182     Yes                1         0
# 160  LaRotonda, William    10038      No                2         1
# 164   LeBlanc, Brandon  R  10134     Yes                1         1
# 255           Singh, Nan   10039      No                0         0
# 259      Smith, Leigh Ann  10153     Yes                1         0
# 268      Steans, Tyrone    10147      No                0         1
#
#      EmpStatusID  DeptID  PerfScoreID FromDiversityJobFairID  Salary Term  \
# 227            5       1            3                    Yes   83363  Yes
# 26             1       1            3                    Yes  106367   No
# 29             1       1            3                    Yes   63000   No
# 97             1       1            3                     No   99351   No
# 132            1       1            3                     No   49920  Yes
# 160            1       1            3                     No   64520   No
# 164            1       1            3                     No   93046   No
# 255            1       1            3                     No   51920   No
# 259            5       1            3                    Yes   55000  Yes
# 268            1       1            3                     No   63003   No
#
#      PositionID                  Position State   Zip        DOB Sex  \
# 227          23   Shared Services Manager    MA  2045 1984-11-06  M
# 26           26            Sr. Accountant    MA  2468 1987-04-04   F
# 29            1              Accountant I    MA  1450 1987-11-24   F
# 97           26            Sr. Accountant    MA  2050 1979-04-16   F
# 132           2  Administrative Assistant    MA  2170 1985-09-16   F
# 160           1              Accountant I    MA  1460 1984-04-26  M
# 164          23   Shared Services Manager    MA  1460 1984-06-10  M
# 255           2  Administrative Assistant    MA  2330 1988-05-19   F
# 259           2  Administrative Assistant    MA  1844 1987-06-14   F
# 268           1              Accountant I    MA  2703 1986-09-01  M
#
#     MaritalDesc          CitizenDesc HispanicLatino  \
# 227     Married  Eligible NonCitizen             No
# 26      Married           US Citizen             No
# 29      Married           US Citizen             No
# 97      Married           US Citizen             No
# 132     Married           US Citizen             No
# 160    Divorced           US Citizen             No
# 164     Married           US Citizen             No
# 255      Single           US Citizen             No
# 259     Married           US Citizen             No
# 268      Single           US Citizen             No
#
#                       RaceDesc DateofHire DateofTermination  \
# 227  Black or African American 2011-02-21        2015-08-15
# 26   Black or African American 2015-02-16               NaT
# 29   Black or African American 2008-10-27               NaT
# 97                       White 2009-01-05               NaT
# 132  Black or African American 2015-02-16        2015-04-15
# 160  Black or African American 2014-01-06               NaT
# 164                      White 2016-01-05               NaT
# 255                      White 2015-05-01               NaT
# 259  Black or African American 2011-09-26        2013-09-25
# 268                      White 2014-09-29               NaT
#
#             TermReason        EmploymentStatus            Department  \
# 227      career change  Voluntarily Terminated  Software Engineering
# 26   N/A-StillEmployed                  Active         Admin Offices
# 29   N/A-StillEmployed                  Active         Admin Offices
# 97   N/A-StillEmployed                  Active         Admin Offices
# 132   no-call, no-show    Terminated for Cause         Admin Offices
# 160  N/A-StillEmployed                  Active         Admin Offices
# 164  N/A-StillEmployed                  Active         Admin Offices
# 255  N/A-StillEmployed                  Active         Admin Offices
# 259      career change  Voluntarily Terminated         Admin Offices
# 268  N/A-StillEmployed                  Active         Admin Offices
#
#             ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 227          Janet King          2  Diversity Job Fair      Fully Meets
# 26   Brandon R. LeBlanc          3  Diversity Job Fair      Fully Meets
# 29   Brandon R. LeBlanc          1  Diversity Job Fair      Fully Meets
# 97   Board of Directors          9               Other      Fully Meets
# 132  Brandon R. LeBlanc          1              Indeed      Fully Meets
# 160  Brandon R. LeBlanc          1             Website      Fully Meets
# 164          Janet King          2       CareerBuilder      Fully Meets
# 255  Brandon R. LeBlanc          1             Website      Fully Meets
# 259  Brandon R. LeBlanc          1  Diversity Job Fair      Fully Meets
# 268  Brandon R. LeBlanc          1              Indeed      Fully Meets
#
#      EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 227              4.15                4                     0
# 26               5.00                4                     3
# 29               4.50                2                     6
# 97               5.00                3                     2
# 132              3.24                3                     4
# 160              5.00                4                     4
# 164              4.10                4                     0
# 255              5.00                3                     5
# 259              3.80                4                     4
# 268              3.90                5                     5
#
#     LastPerformanceReview_Date  DaysLateLast30  Absences
# 227                 2014-04-19               0         4
# 26                  2019-02-18               0         4
# 29                  2019-01-15               0        14
# 97                  2019-02-08               0         3
# 132                 2015-04-15               0         6
# 160                 2019-01-17               0         3
# 164                 2019-01-28               0        20
# 255                 2019-01-15               0         2
# 259                 2013-08-15               0        17
# 268                 2019-01-18               0         9

# %%
hr_dataset['Position'][hr_dataset['Department'] == 'Software Engineering'].value_counts()
# Out:
# Position
# Software Engineer               9
# Software Engineering Manager    1
# Shared Services Manager         1
# Name: count, dtype: int64

# %%
hr_dataset['Department'][hr_dataset['Position'] == 'Shared Services Manager'].value_counts()
# Out:
# Department
# Admin Offices           1
# Software Engineering    1
# Name: count, dtype: int64

# %%
hr_dataset[hr_dataset['Position'] == 'Shared Services Manager']
# Out:
#            Employee_Name  EmpID Married  MaritalStatusID  GenderID  \
# 164  LeBlanc, Brandon  R  10134     Yes                1         1
# 227          Quinn, Sean  10131     Yes                1         1
#
#      EmpStatusID  DeptID  PerfScoreID FromDiversityJobFairID  Salary Term  \
# 164            1       1            3                     No   93046   No
# 227            5       1            3                    Yes   83363  Yes
#
#      PositionID                 Position State   Zip        DOB Sex  \
# 164          23  Shared Services Manager    MA  1460 1984-06-10  M
# 227          23  Shared Services Manager    MA  2045 1984-11-06  M
#
#     MaritalDesc          CitizenDesc HispanicLatino  \
# 164     Married           US Citizen             No
# 227     Married  Eligible NonCitizen             No
#
#                       RaceDesc DateofHire DateofTermination  \
# 164                      White 2016-01-05               NaT
# 227  Black or African American 2011-02-21        2015-08-15
#
#             TermReason        EmploymentStatus            Department  \
# 164  N/A-StillEmployed                  Active         Admin Offices
# 227      career change  Voluntarily Terminated  Software Engineering
#
#     ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 164  Janet King          2       CareerBuilder      Fully Meets
# 227  Janet King          2  Diversity Job Fair      Fully Meets
#
#      EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 164              4.10                4                     0
# 227              4.15                4                     0
#
#     LastPerformanceReview_Date  DaysLateLast30  Absences
# 164                 2019-01-28               0        20
# 227                 2014-04-19               0         4

# %%
# Just 2 people, is not clear no know which is the correct department. Let's see the profiles under Janet:
hr_dataset[hr_dataset['ManagerName'] == 'Janet King']
# Out:
#             Employee_Name  EmpID Married  MaritalStatusID  GenderID  \
# 27         Bozzi, Charles  10175      No                0         1
# 36         Candie, Calvin  10001      No                0         1
# 54      Corleone, Michael  10282      No                2         1
# 55         Corleone, Vito  10019      No                0         1
# 78            Dunn, Amy    10105      No                0         0
# 118       Gray, Elijiah    10098      No                2         1
# 131       Houlihan, Debra  10272     Yes                1         0
# 137     Immediato, Walter  10289     Yes                1         1
# 157           Landa, Hans  10092     Yes                1         1
# 164   LeBlanc, Brandon  R  10134     Yes                1         1
# 167        Liebig, Ketsia  10017     Yes                1         0
# 187       Miller, Brannon  10116      No                0         1
# 218    Peterson, Ebonee    10130     Yes                1         0
# 227           Quinn, Sean  10131     Yes                1         1
# 264        Spirea, Kelley  10090     Yes                1         0
# 271      Sullivan, Kissy   10158     Yes                1         0
# 290         Vega, Vincent  10144      No                2         1
# 296  Wallace, Courtney  E  10274     Yes                1         0
# 308      Zamora, Jennifer  10010      No                0         0
#
#      EmpStatusID  DeptID  PerfScoreID FromDiversityJobFairID  Salary Term  \
# 27             5       5            3                     No   74312  Yes
# 36             1       5            4                     No   72640   No
# 54             1       5            2                     No   68051   No
# 55             1       5            4                     No  170500   No
# 78             1       5            3                     No   75188   No
# 118            1       5            3                     No   62957   No
# 131            1       6            3                     No  180000   No
# 137            5       5            2                     No   83082  Yes
# 157            4       5            3                     No   82758  Yes
# 164            1       1            3                     No   93046   No
# 167            1       5            4                     No   77915   No
# 187            1       5            3                     No   83667   No
# 218            5       5            3                     No   74669  Yes
# 227            5       1            3                    Yes   83363  Yes
# 264            1       5            3                     No   65714   No
# 271            1       5            3                     No   63682   No
# 290            1       5            3                     No   88976   No
# 296            5       5            3                    Yes   80512  Yes
# 308            1       3            4                     No  220450   No
#
#      PositionID                 Position State   Zip        DOB Sex  \
# 27           18       Production Manager    MA  1901 1970-03-10  M
# 36           18       Production Manager    MA  2169 1983-08-09  M
# 54           18       Production Manager    MA  1803 1975-12-17  M
# 55           10   Director of Operations    MA  2030 1983-03-19  M
# 78           18       Production Manager    MA  1731 1973-11-28   F
# 118          18       Production Manager    MA  1752 1981-07-11  M
# 131          11        Director of Sales    RI  2908 2066-03-17   F
# 137          18       Production Manager    MA  2128 1976-11-15  M
# 157          18       Production Manager    MA  1890 1972-07-01  M
# 164          23  Shared Services Manager    MA  1460 1984-06-10  M
# 167          18       Production Manager    MA  2110 1981-10-26   F
# 187          18       Production Manager    MA  2045 1981-08-10  M
# 218          18       Production Manager    MA  2030 1977-05-09   F
# 227          23  Shared Services Manager    MA  2045 1984-11-06  M
# 264          18       Production Manager    MA  2451 1975-09-30   F
# 271          18       Production Manager    MA  1776 1978-03-28   F
# 290          17       Production Manager    MA  2169 2068-10-10  M
# 296          18       Production Manager    MA  2478 2055-11-14   F
# 308           6                      CIO    MA  2067 1979-08-30   F
#
#     MaritalDesc          CitizenDesc HispanicLatino  \
# 27       Single           US Citizen             No
# 36       Single           US Citizen             No
# 54     Divorced           US Citizen             No
# 55       Single           US Citizen             No
# 78       Single           US Citizen             No
# 118    Divorced           US Citizen             No
# 131     Married           US Citizen             No
# 137     Married           US Citizen             No
# 157     Married           US Citizen             No
# 164     Married           US Citizen             No
# 167     Married           US Citizen             No
# 187      Single           US Citizen            Yes
# 218     Married           US Citizen             No
# 227     Married  Eligible NonCitizen             No
# 264     Married           US Citizen             No
# 271     Married           US Citizen             No
# 290    Divorced           US Citizen             No
# 296     Married           US Citizen             No
# 308      Single           US Citizen             No
#
#                       RaceDesc DateofHire DateofTermination  \
# 27                       Asian 2013-09-30        2014-08-07
# 36                       White 2016-01-28               NaT
# 54                       White 2010-07-20               NaT
# 55   Black or African American 2009-01-05               NaT
# 78                       White 2014-09-18               NaT
# 118                      White 2015-06-02               NaT
# 131                      White 2014-05-05               NaT
# 137                      Asian 2011-02-21        2012-09-24
# 157                      White 2011-01-10        2015-12-12
# 164                      White 2016-01-05               NaT
# 167                      White 2013-09-30               NaT
# 187                   Hispanic 2012-08-16               NaT
# 218                      White 2010-10-25        2016-05-18
# 227  Black or African American 2011-02-21        2015-08-15
# 264                      White 2012-10-02               NaT
# 271  Black or African American 2009-01-08               NaT
# 290                      White 2011-08-01               NaT
# 296  Black or African American 2011-09-26        2012-01-02
# 308                      White 2010-04-10               NaT
#
#             TermReason        EmploymentStatus            Department  \
# 27            retiring  Voluntarily Terminated            Production
# 36   N/A-StillEmployed                  Active            Production
# 54   N/A-StillEmployed                  Active            Production
# 55   N/A-StillEmployed                  Active            Production
# 78   N/A-StillEmployed                  Active            Production
# 118  N/A-StillEmployed                  Active            Production
# 131  N/A-StillEmployed                  Active                 Sales
# 137            unhappy  Voluntarily Terminated            Production
# 157         attendance    Terminated for Cause            Production
# 164  N/A-StillEmployed                  Active         Admin Offices
# 167  N/A-StillEmployed                  Active            Production
# 187  N/A-StillEmployed                  Active            Production
# 218   Another position  Voluntarily Terminated            Production
# 227      career change  Voluntarily Terminated  Software Engineering
# 264  N/A-StillEmployed                  Active            Production
# 271  N/A-StillEmployed                  Active            Production
# 290  N/A-StillEmployed                  Active            Production
# 296   Another position  Voluntarily Terminated            Production
# 308  N/A-StillEmployed                  Active                 IT/IS
#
#     ManagerName  ManagerID   RecruitmentSource   PerformanceScore  \
# 27   Janet King          2              Indeed        Fully Meets
# 36   Janet King          2              Indeed            Exceeds
# 54   Janet King          2       CareerBuilder  Needs Improvement
# 55   Janet King          2              Indeed            Exceeds
# 78   Janet King          2       Google Search        Fully Meets
# 118  Janet King          2   Employee Referral        Fully Meets
# 131  Janet King          2            LinkedIn        Fully Meets
# 137  Janet King          2              Indeed  Needs Improvement
# 157  Janet King          2   Employee Referral        Fully Meets
# 164  Janet King          2       CareerBuilder        Fully Meets
# 167  Janet King          2             Website            Exceeds
# 187  Janet King          2              Indeed        Fully Meets
# 218  Janet King          2              Indeed        Fully Meets
# 227  Janet King          2  Diversity Job Fair        Fully Meets
# 264  Janet King          2            LinkedIn        Fully Meets
# 271  Janet King          2              Indeed        Fully Meets
# 290  Janet King          2   Employee Referral        Fully Meets
# 296  Janet King          2  Diversity Job Fair        Fully Meets
# 308  Janet King          2   Employee Referral            Exceeds
#
#      EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 27               3.39                3                     0
# 36               5.00                3                     0
# 54               4.13                2                     0
# 55               3.70                5                     0
# 78               4.52                4                     0
# 118              4.63                3                     0
# 131              4.50                4                     0
# 137              2.34                2                     0
# 157              4.78                4                     0
# 164              4.10                4                     0
# 167              4.10                3                     0
# 187              4.37                3                     0
# 218              4.16                5                     0
# 227              4.15                4                     0
# 264              4.83                5                     0
# 271              3.73                4                     0
# 290              3.93                3                     0
# 296              4.50                3                     0
# 308              4.60                5                     6
#
#     LastPerformanceReview_Date  DaysLateLast30  Absences
# 27                  2014-02-20               0        14
# 36                  2019-02-22               0        14
# 54                  2019-01-14               3         3
# 55                  2019-02-04               0        15
# 78                  2019-01-15               0         4
# 118                 2019-01-04               0         2
# 131                 2019-01-21               0        19
# 137                 2012-04-12               3         4
# 157                 2015-02-15               0         9
# 164                 2019-01-28               0        20
# 167                 2019-01-21               0        11
# 187                 2019-01-14               0         2
# 218                 2015-03-05               0         6
# 227                 2014-04-19               0         4
# 264                 2019-02-14               0        15
# 271                 2019-01-24               0        12
# 290                 2019-02-27               0        19
# 296                 2012-01-02               0         5
# 308                 2019-02-21               0        16

# %% [markdown]
# All of them are Managers or directors, so assuming the incorrect line is the "Software Engineer":

# %%
hr_dataset['Department'][hr_dataset['Position'] == 'Shared Services Manager'] = 'Admin Offices'
# Out:
# /tmp/ipykernel_7087/2325074023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_dataset['Department'][hr_dataset['Position'] == 'Shared Services Manager'] = 'Admin Offices'

# %%
hr_dataset['Department'][hr_dataset['Position'] == 'Shared Services Manager'].value_counts()
# Out:
# Department
# Admin Offices    2
# Name: count, dtype: int64

# %% [markdown]
# ___
# 3.8. Exporting cleaned data base

# %%
hr_dataset.to_csv('../data/HR_dataset/HR_Dataset_clean.csv')

# %% [markdown]
# ___
# ___
# ## 4. ANALYSIS QUESTIONS:
#
# ### Engagement
# - Relation between `EngagementSurvey` and `SpecialProjectsCount`?
# - Relation between `EmpSatisfaction` and `SpecialProjectsCount`?
# - Relation between `Absences` and `EngagementSurvey`?
# - Relation between `DaysLateLast30` and `EngagementSurvey`?
# - Relation between `PerformanceScore` and `EmpSatisfaction`?
# - Relation between `LastPerformanceReview_Date` and `ManagerID`?
# - Relation between `EmpSatisfaction` and `Salary`?
#
# ### Attrition
# - Relation between `Termd` and `ManagerID`?
# - Relation between `Termd` and `Position`?
# - Relation between `Termd` and `Department`?
#
# ### Diversity
# - What is the overall diversity `Sex` profile of the organization?
# - What is the overall diversity `RaceDesc` profile of the organization?
#
# ### Workers differencies
# - Relation between `RecruitmentSource` and `Salary`?
# - Relation between `Sex` and `Salary`?
# - Relation between `RaceDesc` and `Salary`?
# - Relation between `Department` and `Salary`?

# %%
# Let's check main relations in numeric categories:
plt.figure(figsize = (20,15))
sns.heatmap(hr_dataset.corr(), cmap = "crest", annot = True,
            vmin = -1, vmax = 1);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /mnt/c/Users/aseoa/OneDrive/Escritorio/Adalab/personal-project/1.Exploring_HRDataset.ipynb Cell 85 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/aseoa/OneDrive/Escritorio/Adalab/personal-project/1.Exploring_HRDataset.ipynb#Y102sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Let's check main relations in numeric categories:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/aseoa/OneDrive/Escritorio/Adalab/personal-project/1.Exploring_HRDataset.ipynb#Y102sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.figure(figsize = (20,15))
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/aseoa/OneDrive/Escritorio/Adalab/personal-project/1.Exploring_HRDataset.ipynb#Y102sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> sns.heatmap(hr_dataset.corr(), cmap = "crest", annot = True,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/aseoa/OneDrive/Escritorio/Adalab/personal-project/1.Exploring_HRDataset.ipynb#Y102sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>             vmin = -1, vmax = 1);
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/internals/managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/internals/managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Adinolfi, Wilson  K'
